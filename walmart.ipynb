# %% [markdown]
# <a href="https://colab.research.google.com/github/sachinbb7/walmart/blob/main/walmart.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as  pd
import numpy as np

# %%
from google.colab import files
files.upload()  # Choose the kaggle.json file you just downloaded
# Out:
#      <input type="file" id="files-83b97ac5-2435-466e-81c1-1fd00ef8bbba" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-83b97ac5-2435-466e-81c1-1fd00ef8bbba">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !mkdir -p ~/.kaggle
# !mv kaggle.json ~/.kaggle/
# !chmod 600 ~/.kaggle/kaggle.json

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("najir0123/walmart-10k-sales-datasets")

print("Path to dataset files:", path)
# Out:
# ...
# 100%|██████████| 143k/143k [00:00<00:00, 55.9MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/najir0123/walmart-10k-sales-datasets/versions/1

# %%
import os
os.listdir("/root/.cache/kagglehub/datasets/najir0123/walmart-10k-sales-datasets/versions/1")
# Out:
# ['Walmart.csv']

# %%
df= pd.read_csv("/root/.cache/kagglehub/datasets/najir0123/walmart-10k-sales-datasets/versions/1/Walmart.csv", index_col = "invoice_id")

# %%
df.head()
# Out:
#              Branch         City                category unit_price  quantity  \
# invoice_id
# 1           WALM003  San Antonio       Health and beauty     $74.69       7.0
# 2           WALM048    Harlingen  Electronic accessories     $15.28       5.0
# 3           WALM067  Haltom City      Home and lifestyle     $46.33       7.0
# 4           WALM064      Bedford       Health and beauty     $58.22       8.0
# 5           WALM013       Irving       Sports and travel     $86.31       7.0
#
#                 date      time payment_method  rating  profit_margin
# invoice_id
# 1           05/01/19  13:08:00        Ewallet     9.1           0.48
# 2           08/03/19  10:29:00           Cash     9.6           0.48
# 3           03/03/19  13:23:00    Credit card     7.4           0.33
# 4           27/01/19  20:33:00        Ewallet     8.4           0.33
# 5           08/02/19  10:37:00        Ewallet     5.3           0.48

# %%
df['date']= pd.to_datetime(df['date'], infer_datetime_format=True, errors='coerce')
# Out:
# /tmp/ipython-input-701836342.py:1: UserWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df['date']= pd.to_datetime(df['date'], infer_datetime_format=True, errors='coerce')
# /tmp/ipython-input-701836342.py:1: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df['date']= pd.to_datetime(df['date'], infer_datetime_format=True, errors='coerce')

# %%
df.head()
# Out:
#              Branch         City                category unit_price  quantity  \
# invoice_id
# 1           WALM003  San Antonio       Health and beauty     $74.69       7.0
# 2           WALM048    Harlingen  Electronic accessories     $15.28       5.0
# 3           WALM067  Haltom City      Home and lifestyle     $46.33       7.0
# 4           WALM064      Bedford       Health and beauty     $58.22       8.0
# 5           WALM013       Irving       Sports and travel     $86.31       7.0
#
#                  date      time payment_method  rating  profit_margin
# invoice_id
# 1          2019-05-01  13:08:00        Ewallet     9.1           0.48
# 2          2019-08-03  10:29:00           Cash     9.6           0.48
# 3          2019-03-03  13:23:00    Credit card     7.4           0.33
# 4          2019-01-27  20:33:00        Ewallet     8.4           0.33
# 5          2019-08-02  10:37:00        Ewallet     5.3           0.48

# %%
df.describe()
# Out:
#            quantity        rating  profit_margin
# count  10020.000000  10051.000000   10051.000000
# mean       2.353493      5.825659       0.393791
# std        1.602658      1.763991       0.090669
# min        1.000000      3.000000       0.180000
# 25%        1.000000      4.000000       0.330000
# 50%        2.000000      6.000000       0.330000
# 75%        3.000000      7.000000       0.480000
# max       10.000000     10.000000       0.570000

# %%
df.shape
# Out:
# (10051, 10)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10051 entries, 1 to 10000
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Branch          10051 non-null  object
#  1   City            10051 non-null  object
#  2   category        10051 non-null  object
#  3   unit_price      10020 non-null  object
#  4   quantity        10020 non-null  float64
#  5   date            10051 non-null  datetime64[ns]
#  6   time            10051 non-null  object
#  7   payment_method  10051 non-null  object
#  8   rating          10051 non-null  float64
#  9   profit_margin   10051 non-null  float64
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 863.8+ KB

# %%
df.select_dtypes(include='object').dtypes
# Out:
# Branch            object
# City              object
# category          object
# unit_price        object
# time              object
# payment_method    object
# dtype: object

# %%
df.select_dtypes(include=['float64', 'int']).dtypes
# Out:
# quantity         float64
# rating           float64
# profit_margin    float64
# dtype: object

# %%
df.duplicated().sum()
# Out:
# np.int64(51)

# %%
df.drop_duplicates(keep= 'first', inplace =True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.shape
# Out:
# (10000, 10)

# %%
df.isna().sum()
# Out:
# Branch             0
# City               0
# category           0
# unit_price        31
# quantity          31
# date               0
# time               0
# payment_method     0
# rating             0
# profit_margin      0
# dtype: int64

# %%
#dropping nulls since null records contributes to 0.31% of data

df.dropna(inplace=True)
df.isna().sum()
# Out:
# Branch            0
# City              0
# category          0
# unit_price        0
# quantity          0
# date              0
# time              0
# payment_method    0
# rating            0
# profit_margin     0
# dtype: int64

# %%
df.columns= df.columns.str.lower()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9969 entries, 1 to 10000
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   branch          9969 non-null   object
#  1   city            9969 non-null   object
#  2   category        9969 non-null   object
#  3   unit_price      9969 non-null   object
#  4   quantity        9969 non-null   float64
#  5   date            9969 non-null   datetime64[ns]
#  6   time            9969 non-null   object
#  7   payment_method  9969 non-null   object
#  8   rating          9969 non-null   float64
#  9   profit_margin   9969 non-null   float64
# dtypes: datetime64[ns](1), float64(3), object(6)
# memory usage: 856.7+ KB

# %%
#convert unit_price to float
df["unit_price"]= df['unit_price'].str.replace('$', '').astype(float)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9969 entries, 1 to 10000
# Data columns (total 10 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   branch          9969 non-null   object
#  1   city            9969 non-null   object
#  2   category        9969 non-null   object
#  3   unit_price      9969 non-null   float64
#  4   quantity        9969 non-null   float64
#  5   date            9969 non-null   datetime64[ns]
#  6   time            9969 non-null   object
#  7   payment_method  9969 non-null   object
#  8   rating          9969 non-null   float64
#  9   profit_margin   9969 non-null   float64
# dtypes: datetime64[ns](1), float64(4), object(5)
# memory usage: 856.7+ KB

# %%
df['total']= df['unit_price']* df['quantity']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9969 entries, 1 to 10000
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   branch          9969 non-null   object
#  1   city            9969 non-null   object
#  2   category        9969 non-null   object
#  3   unit_price      9969 non-null   float64
#  4   quantity        9969 non-null   float64
#  5   date            9969 non-null   datetime64[ns]
#  6   time            9969 non-null   object
#  7   payment_method  9969 non-null   object
#  8   rating          9969 non-null   float64
#  9   profit_margin   9969 non-null   float64
#  10  total           9969 non-null   float64
# dtypes: datetime64[ns](1), float64(5), object(5)
# memory usage: 934.6+ KB

# %%
df.to_csv("walmart_cleaned_data.csv")
